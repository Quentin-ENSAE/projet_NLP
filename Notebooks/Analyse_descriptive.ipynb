# %% [markdown]
# # Analyse Statistique Dataset
#
# ---
# - Justification lignes supprimées
# - Top 20 mots
# - description nombre de mot, nombre de token
# - Nombre de classes moyenne
# - Distribution des classes
# ---

# %% [markdown]
# ## Import data

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm  # Barre de progression pour Jupyter
pd.set_option('display.max_colwidth', None)
from IPython.display import display, Markdown

import nltk
from wordcloud import WordCloud
from collections import Counter
from nltk.corpus import stopwords
import re

# %%
import os
import s3fs
os.environ["AWS_ACCESS_KEY_ID"] = 'PG1XLIX2BY3P3BRECRJQ'
os.environ["AWS_SECRET_ACCESS_KEY"] = '+Mf8EF6sSat8xMorwl1BZLZZBF+Hcj2UHJ4DRZrs'
os.environ["AWS_SESSION_TOKEN"] = 'eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.....cO3MC8ZtjXLoAuYJzNi1BvPaTGQWRyMkyHT3Aakd8S6e0PvkeArmoRyzbeKOyb-amkhwkL5JNfxHsIl_t9aESw'
os.environ["AWS_DEFAULT_REGION"] = 'us-east-1'
fs = s3fs.S3FileSystem(
    client_kwargs={'endpoint_url': 'https://'+'minio.lab.sspcloud.fr'},
    key = os.environ["AWS_ACCESS_KEY_ID"], 
    secret = os.environ["AWS_SECRET_ACCESS_KEY"], 
    token = os.environ["AWS_SESSION_TOKEN"])

# %%
print(repr(os.getenv("AWS_ACCESS_KEY_ID")))
print(repr(os.getenv("AWS_SECRET_ACCESS_KEY")))
# Out:
# 'PG1XLIX2BY3P3BRECRJQ'
# '+Mf8EF6sSat8xMorwl1BZLZZBF+Hcj2UHJ4DRZrs'

# %%
if not os.path.exists("../data/df_target_V2.pkl"):
    BUCKET = "s3://quentin1999/Data_Projet_NLP"
    FILE_KEY_S3 = "df_target_V2.pkl"
    FILE_PATH_S3 = BUCKET + "/" + FILE_KEY_S3

    with fs.open(FILE_PATH_S3, mode="rb") as file_in:
        df = pd.read_pickle(file_in)

    print("✅ Fichier chargé avec succès, shape :", df.shape)

    df.to_pickle("../data/df_target_V2.pkl")

    print("✅ Fichier sauvegardé avec succès dans le dossier data")

# %% [markdown]
# raise RuntimeError("⛔ Cette cellule ne doit pas être exécutée.")
#
# # Create filesystem object
# S3_ENDPOINT_URL = "https://" + os.environ["AWS_S3_ENDPOINT"]
# fs = s3fs.S3FileSystem(client_kwargs={'endpoint_url': S3_ENDPOINT_URL})
#
# BUCKET_OUT = "s3://quentin1999/Data_Projet_NLP"
# FILE_KEY_OUT_S3 = "df_final"
# FILE_PATH_OUT_S3 = BUCKET_OUT + "/" + FILE_KEY_OUT_S3
#
# with fs.open(FILE_PATH_OUT_S3, 'w') as file_out:
#     df.to_csv(file_out)

# %% [markdown]
# raise RuntimeError("⛔ Cette cellule ne doit pas être exécutée.")
#
# BUCKET_OUT = "s3://quentin1999/Data_Projet_NLP"
# FILE_KEY_OUT_S3 = "df_metadata"
# FILE_PATH_OUT_S3 = BUCKET_OUT + "/" + FILE_KEY_OUT_S3
#
# with fs.open(FILE_PATH_OUT_S3, 'w') as file_out:
#     df_metadata.to_csv(file_out)

# %% [markdown]
# ## Selection des cas cliniques

# %%
df = pd.read_pickle('../data/df_target_V2.pkl')

# %%
df.shape
# Out:
# (10718, 12)

# %%
# On convertit chaque élément en array bool explicite
target_array = np.vstack(df['target'].apply(lambda x: np.array(x, dtype=bool)))

# %%
MeSH_vides = df[df['target'].apply(lambda x: not any(x))]
print("nombre cas sans code MeSH catégorie 'disease' :", MeSH_vides.shape)

df = df.drop(MeSH_vides.index)
# Out:
# nombre cas sans code MeSH catégorie 'disease' : (667, 12)

# %%
keys = [f"C{str(i).zfill(2)}" for i in range(1, 27)]
values = target_array.sum(axis=0)
result = dict(zip(keys, values))

cas_par_classes = pd.DataFrame.from_dict(result, orient='index', columns=['nombre_cas'])
cas_par_classes
# Out:
#      nombre_cas
# C01        2343
# C02           0
# C03           0
# C04        2998
# C05        1008
# C06        1519
# C07         392
# C08        1567
# C09         261
# C10        2136
# C11         667
# C12        1373
# C13           0
# C14        1936
# C15        1305
# C16        1430
# C17        1387
# C18         850
# C19         940
# C20        1570
# C21           0
# C22           7
# C23        2860
# C24          28
# C25         214
# C26         576

# %%
print("nombre de classes avec 100+ cas :", (cas_par_classes > 100).sum().iloc[0])
print("nombre de classes avec 1000+ cas :", (cas_par_classes > 1000).sum().iloc[0])
# Out:
# nombre de classes avec 100+ cas : 20
# nombre de classes avec 1000+ cas : 13

# %%
print("Nombre de label au total: ", cas_par_classes.sum().iloc[0])
print("Nombre de catégorie par cas clinique en moyenne: ", round((cas_par_classes.sum().iloc[0] / df.shape[0]),2))
print("Nombre de cas par catégorie moyenne: ", round((cas_par_classes.sum().iloc[0] / 23),2))
# Out:
# Nombre de label au total:  27367
# Nombre de catégorie par cas clinique en moyenne:  2.72
# Nombre de cas par catégorie moyenne:  1189.87

# %%
# Tracer un barplot
plt.figure(figsize=(10, 6))
plt.bar(cas_par_classes.index, cas_par_classes['nombre_cas'])
plt.xlabel('Classes')
plt.ylabel('Nombre de cas')
plt.title('Nombre de cas par classe MeSH (catégorie "disease")')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Matrice de corrélation entre les classes

# %%
import numpy as np
import pandas as pd

# 1. Ton array de base
arr_int = target_array.astype(int)

# 2. Générer TOUS les noms d'origine
full_category_names = [f"C{str(i+1).zfill(2)}" for i in range(arr_int.shape[1])]

# 3. Détecter colonnes non constantes
non_constant_columns = arr_int.std(axis=0) != 0

# 4. Réduire arr_int en gardant trace
arr_int = arr_int[:, non_constant_columns]

# 5. Garder uniquement les catégories non constantes
category_names = [name for name, keep in zip(full_category_names, non_constant_columns) if keep]

# 6. Calcul de la corrélation
correlation_matrix = np.corrcoef(arr_int, rowvar=False)

# 7. Masquer le triangle inférieur
mask = np.tril(np.ones_like(correlation_matrix, dtype=bool))
correlation_matrix = np.where(mask, np.nan, correlation_matrix)

# 8. Créer un DataFrame avec les noms corrects
correlation_df = pd.DataFrame(correlation_matrix, index=category_names, columns=category_names)

# 9. Fonction de stylisation
def style_corr(val):
    if pd.isna(val):
        return ""
    style = ""
    if abs(val) > 0.10:
        style += "font-weight: bold;"
    return style

# 10. Appliquer le style
styled_corr = (
    correlation_df.style
    .format(precision=2, na_rep="")  # 2 chiffres
    .background_gradient(cmap='RdYlGn', vmin=-1, vmax=1)  # couleurs
    .applymap(style_corr)  # gras si |corr| > 0.10
    .set_properties(**{'font-size': '10pt'})  # taille police
    .set_caption("Matrice de corrélation (triangle supérieur) entre classes MeSH C01 à C26")
)

# 11. Afficher
styled_corr
# Out:
# /tmp/ipykernel_2522/976907673.py:43: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(style_corr)  # gras si |corr| > 0.10
# <style type="text/css">
# #T_e508e_row0_col0, #T_e508e_row1_col0, #T_e508e_row1_col1, #T_e508e_row2_col0, #T_e508e_row2_col1, #T_e508e_row2_col2, #T_e508e_row3_col0, #T_e508e_row3_col1, #T_e508e_row3_col2, #T_e508e_row3_col3, #T_e508e_row4_col0, #T_e508e_row4_col1, #T_e508e_row4_col2, #T_e508e_row4_col3, #T_e508e_row4_col4, #T_e508e_row5_col0, #T_e508e_row5_col1, #T_e508e_row5_col2, #T_e508e_row5_col3, #T_e508e_row5_col4, #T_e508e_row5_col5, #T_e508e_row6_col0, #T_e508e_row6_col1, #T_e508e_row6_col2, #T_e508e_row6_col3, #T_e508e_row6_col4, #T_e508e_row6_col5, #T_e508e_row6_col6, #T_e508e_row7_col0, #T_e508e_row7_col1, #T_e508e_row7_col2, #T_e508e_row7_col3, #T_e508e_row7_col4, #T_e508e_row7_col5, #T_e508e_row7_col6, #T_e508e_row7_col7, #T_e508e_row8_col0, #T_e508e_row8_col1, #T_e508e_row8_col2, #T_e508e_row8_col3, #T_e508e_row8_col4, #T_e508e_row8_col5, #T_e508e_row8_col6, #T_e508e_row8_col7, #T_e508e_row8_col8, #T_e508e_row9_col0, #T_e508e_row9_col1, #T_e508e_row9_col2, #T_e508e_row9_col3, #T_e508e_row9_col4, #T_e508e_row9_col5, #T_e508e_row9_col6, #T_e508e_row9_col7, #T_e508e_row9_col8, #T_e508e_row9_col9, #T_e508e_row10_col0, #T_e508e_row10_col1, #T_e508e_row10_col2, #T_e508e_row10_col3, #T_e508e_row10_col4, #T_e508e_row10_col5, #T_e508e_row10_col6, #T_e508e_row10_col7, #T_e508e_row10_col8, #T_e508e_row10_col9, #T_e508e_row10_col10, #T_e508e_row11_col0, #T_e508e_row11_col1, #T_e508e_row11_col2, #T_e508e_row11_col3, #T_e508e_row11_col4, #T_e508e_row11_col5, #T_e508e_row11_col6, #T_e508e_row11_col7, #T_e508e_row11_col8, #T_e508e_row11_col9, #T_e508e_row11_col10, #T_e508e_row11_col11, #T_e508e_row12_col0, #T_e508e_row12_col1, #T_e508e_row12_col2, #T_e508e_row12_col3, #T_e508e_row12_col4, #T_e508e_row12_col5, #T_e508e_row12_col6, #T_e508e_row12_col7, #T_e508e_row12_col8, #T_e508e_row12_col9, #T_e508e_row12_col10, #T_e508e_row12_col11, #T_e508e_row12_col12, #T_e508e_row13_col0, #T_e508e_row13_col1, #T_e508e_row13_col2, #T_e508e_row13_col3, #T_e508e_row13_col4, #T_e508e_row13_col5, #T_e508e_row13_col6, #T_e508e_row13_col7, #T_e508e_row13_col8, #T_e508e_row13_col9, #T_e508e_row13_col10, #T_e508e_row13_col11, #T_e508e_row13_col12, #T_e508e_row13_col13, #T_e508e_row14_col0, #T_e508e_row14_col1, #T_e508e_row14_col2, #T_e508e_row14_col3, #T_e508e_row14_col4, #T_e508e_row14_col5, #T_e508e_row14_col6, #T_e508e_row14_col7, #T_e508e_row14_col8, #T_e508e_row14_col9, #T_e508e_row14_col10, #T_e508e_row14_col11, #T_e508e_row14_col12, #T_e508e_row14_col13, #T_e508e_row14_col14, #T_e508e_row15_col0, #T_e508e_row15_col1, #T_e508e_row15_col2, #T_e508e_row15_col3, #T_e508e_row15_col4, #T_e508e_row15_col5, #T_e508e_row15_col6, #T_e508e_row15_col7, #T_e508e_row15_col8, #T_e508e_row15_col9, #T_e508e_row15_col10, #T_e508e_row15_col11, #T_e508e_row15_col12, #T_e508e_row15_col13, #T_e508e_row15_col14, #T_e508e_row15_col15, #T_e508e_row16_col0, #T_e508e_row16_col1, #T_e508e_row16_col2, #T_e508e_row16_col3, #T_e508e_row16_col4, #T_e508e_row16_col5, #T_e508e_row16_col6, #T_e508e_row16_col7, #T_e508e_row16_col8, #T_e508e_row16_col9, #T_e508e_row16_col10, #T_e508e_row16_col11, #T_e508e_row16_col12, #T_e508e_row16_col13, #T_e508e_row16_col14, #T_e508e_row16_col15, #T_e508e_row16_col16, #T_e508e_row17_col0, #T_e508e_row17_col1, #T_e508e_row17_col2, #T_e508e_row17_col3, #T_e508e_row17_col4, #T_e508e_row17_col5, #T_e508e_row17_col6, #T_e508e_row17_col7, #T_e508e_row17_col8, #T_e508e_row17_col9, #T_e508e_row17_col10, #T_e508e_row17_col11, #T_e508e_row17_col12, #T_e508e_row17_col13, #T_e508e_row17_col14, #T_e508e_row17_col15, #T_e508e_row17_col16, #T_e508e_row17_col17, #T_e508e_row18_col0, #T_e508e_row18_col1, #T_e508e_row18_col2, #T_e508e_row18_col3, #T_e508e_row18_col4, #T_e508e_row18_col5, #T_e508e_row18_col6, #T_e508e_row18_col7, #T_e508e_row18_col8, #T_e508e_row18_col9, #T_e508e_row18_col10, #T_e508e_row18_col11, #T_e508e_row18_col12, #T_e508e_row18_col13, #T_e508e_row18_col14, #T_e508e_row18_col15, #T_e508e_row18_col16, #T_e508e_row18_col17, #T_e508e_row18_col18, #T_e508e_row19_col0, ...
#   background-color: #000000;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e508e_row0_col1 {
#   background-color: #fee18d;
#   color: #000000;
#   font-weight: bold;
#   font-size: 10pt;
# }
# #T_e508e_row0_col2, #T_e508e_row2_col5, #T_e508e_row10_col15, #T_e508e_row11_col15, #T_e508e_row12_col16, #T_e508e_row12_col21, #T_e508e_row15_col21 {
#   background-color: #fff7b2;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e508e_row0_col3, #T_e508e_row0_col13, #T_e508e_row2_col19, #T_e508e_row3_col6, #T_e508e_row4_col17, #T_e508e_row4_col19, #T_e508e_row6_col17, #T_e508e_row7_col17, #T_e508e_row7_col20, #T_e508e_row8_col14, #T_e508e_row8_col21, #T_e508e_row9_col12, #T_e508e_row10_col21, #T_e508e_row11_col18, #T_e508e_row14_col17, #T_e508e_row14_col20, #T_e508e_row15_col19, #T_e508e_row16_col17, #T_e508e_row17_col19, #T_e508e_row17_col20, #T_e508e_row17_col21, #T_e508e_row18_col20 {
#   background-color: #fffebe;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e508e_row0_col4, #T_e508e_row2_col20, #T_e508e_row3_col4, #T_e508e_row3_col12, #T_e508e_row4_col5, #T_e508e_row6_col9, #T_e508e_row8_col15, #T_e508e_row15_col20 {
#   background-color: #fffbb8;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e508e_row0_col5 {
#   background-color: #c7e77f;
#   color: #000000;
#   font-weight: bold;
#   font-size: 10pt;
# }
# #T_e508e_row0_col6, #T_e508e_row1_col2, #T_e508e_row3_col20, #T_e508e_row6_col19, #T_e508e_row8_col18, #T_e508e_row8_col19, #T_e508e_row10_col11, #T_e508e_row10_col13, #T_e508e_row12_col17, #T_e508e_row12_col18, #T_e508e_row13_col17, #T_e508e_row13_col19, #T_e508e_row17_col18, #T_e508e_row19_col21, #T_e508e_row20_col21 {
#   background-color: #feffbe;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e508e_row0_col7, #T_e508e_row1_col8, #T_e508e_row2_col10, #T_e508e_row3_col13, #T_e508e_row5_col12, #T_e508e_row5_col14, #T_e508e_row7_col13, #T_e508e_row11_col21, #T_e508e_row13_col15 {
#   background-color: #fff6b0;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e508e_row0_col8, #T_e508e_row0_col18, #T_e508e_row1_col17, #T_e508e_row4_col7, #T_e508e_row4_col10, #T_e508e_row4_col11, #T_e508e_row4_col18, #T_e508e_row5_col10, #T_e508e_row5_col18, #T_e508e_row5_col20, #T_e508e_row6_col14, #T_e508e_row6_col15, #T_e508e_row6_col16, #T_e508e_row6_col20, #T_e508e_row8_col20, #T_e508e_row9_col11, #T_e508e_row9_col20, #T_e508e_row10_col20, #T_e508e_row12_col19 {
#   background-color: #fffcba;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e508e_row0_col9, #T_e508e_row1_col6, #T_e508e_row1_col13, #T_e508e_row3_col17, #T_e508e_row4_col12, #T_e508e_row7_col10, #T_e508e_row7_col15, #T_e508e_row12_col15 {
#   background-color: #f8fcb6;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e50

# %% [markdown]
# #### Brouillon

# %% [markdown]
#     # Convertir en int
#     arr_int = target_array.astype(int)
#
#     # Supprimer les colonnes constantes (écart-type nul)
#     #arr_int = arr_int[:, arr_int.std(axis=0) != 0]
#
#     # Calculer la corrélation
#     correlation_matrix = np.corrcoef(arr_int, rowvar=False)
#
#     # Masquer le triangle inférieur
#     mask = np.tril(np.ones_like(correlation_matrix, dtype=bool))
#     correlation_matrix = np.where(mask, np.nan, correlation_matrix)
#
#     # Créer un DataFrame
#     correlation_df = pd.DataFrame(correlation_matrix)
#
#     # Appliquer un style : format 2 chiffres, couleurs selon valeur
#     styled_corr = correlation_df.style \
#         .format(precision=2, na_rep="") \
#         .background_gradient(cmap='RdYlGn', vmin=-1, vmax=1) \
#         .set_properties(**{'font-size': '10pt'}) \
#         .set_caption("Matrice de corrélation (triangle supérieur seulement)")
#
#     # Afficher dans Jupyter
#     styled_corr

# %%
#pip install tabulate

# %% [markdown]
#     # 1. Convertir en int
#     arr_int = target_array.astype(int)
#
#     # 2. Calculer la matrice de corrélation
#     correlation_matrix = np.corrcoef(arr_int, rowvar=False)
#
#     # 3. Masquer le triangle inférieur
#     mask = np.tril(np.ones_like(correlation_matrix, dtype=bool))
#     correlation_matrix_masked = np.where(mask, np.nan, correlation_matrix)
#
#     # 4. Mettre dans un DataFrame
#     correlation_df = pd.DataFrame(correlation_matrix_masked)
#
#     # 5. Fonction de formatage
#     def highlight_corr(val):
#         if np.isnan(val):
#             return ""  # ne rien afficher pour les NaN
#         val_rounded = f"{val:.2f}"
#         if abs(val) > 0.10:
#             return f"**{val_rounded}**"  # mettre en gras
#         else:
#             return val_rounded
#
#     # 6. Appliquer le formatage
#     formatted_corr_df = correlation_df.applymap(highlight_corr)
#
#     # 7. Afficher joliment en markdown
#     md_table = formatted_corr_df.to_markdown(index=False)
#     display(Markdown(md_table))

# %% [markdown]
# ## Analyse case_text

# %%
# Statistiques nombre de caractères
df['case_text'].str.len().describe().astype(int)
# Out:
# count    10051
# mean      3502
# std       2399
# min        145
# 25%       2004
# 50%       3012
# 75%       4343
# max      60512
# Name: case_text, dtype: int64

# %%
# Statistiques nombre de mots
df['case_text'].apply(lambda x: len(str(x).split())).describe().astype(int)
# Out:
# count    10051
# mean       524
# std        360
# min         25
# 25%        300
# 50%        452
# 75%        648
# max       8797
# Name: case_text, dtype: int64

# %% [markdown]
# ### Nuage de mots ordinaires

# %%
from nltk.corpus import stopwords 
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/onyxia/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
text_brut = " ".join(df['case_text'].astype(str))
STOPWORDS = set(stopwords.words('english'))

# Nettoyer et découper en mots
words = re.findall(r'\b\w+\b', text_brut.lower())
words = [word for word in words if word not in STOPWORDS and len(word) > 2]

# Compte les occurrences des mots
term_counts = Counter(words)

# Prend les 20 mots les plus fréquents
most_common_terms = term_counts.most_common(20)

# Affiche proprement en texte
print("Top 20 des mots les plus fréquents :")
for term, count in most_common_terms:
    print(f"{term}: {count}")
# Out:
# Top 20 des mots les plus fréquents :
# patient: 42208
# showed: 21150
# figure: 19926
# normal: 17939
# revealed: 16054
# left: 15717
# right: 15197
# day: 14040
# blood: 13655
# examination: 12687
# treatment: 11966
# year: 11738
# performed: 10850
# old: 10724
# fig: 10646
# history: 10253
# months: 10033
# cells: 9616
# days: 8983
# also: 8185

# %%
# Display one wordcloud for each of the most frequent classes
x, y = np.ogrid[:300, :300]
mask = (x - 150) ** 2 + (y - 150) ** 2 > 130 ** 2
mask = 255 * mask.astype(int)

# plot a word cloud
text = str(df['case_text'])
wc = WordCloud(background_color="white", repeat=True, mask=mask, stopwords = STOPWORDS)
wc.generate(text)

plt.axis("off")
plt.imshow(wc, interpolation="bilinear")
plt.show()

# %% [markdown]
# ### Nuage de mots médicaux

# %%
import spacy
import scispacy
from scispacy.linking import EntityLinker
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# Load the Med7 model
nlp = spacy.load("en_core_sci_sm")

# Ajouter un linker vers UMLS (si tu veux mapper les entités à des concepts médicaux précis)
linker = EntityLinker(resolve_abbreviations=True, name="umls")
nlp.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls"})
# Out:
# /opt/conda/lib/python3.12/site-packages/spacy/language.py:2195: FutureWarning: Possible set union at position 6328
#   deserializers["tokenizer"] = lambda p: self.tokenizer.from_disk(  # type: ignore[union-attr]
# https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/data/linkers/2023-04-23/umls/tfidf_vectors_sparse.npz not found in cache, downloading to /tmp/tmpn9y588f_
# 100%|██████████| 492M/492M [00:27<00:00, 18.8MiB/s]
# Finished download, copying /tmp/tmpn9y588f_ to cache at /home/onyxia/.scispacy/datasets/2b79923846fb52e62d686f2db846392575c8eb5b732d9d26cd3ca9378c622d40.87bd52d0f0ee055c1e455ef54ba45149d188552f07991b765da256a1b512ca0b.tfidf_vectors_sparse.npz
# https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/data/linkers/2023-04-23/umls/nmslib_index.bin not found in cache, downloading to /tmp/tmpl0350og0
# 100%|██████████| 724M/724M [00:39<00:00, 19.4MiB/s]
# Finished download, copying /tmp/tmpl0350og0 to cache at /home/onyxia/.scispacy/datasets/7e8e091ec80370b87b1652f461eae9d926e543a403a69c1f0968f71157322c25.6d801a1e14867953e36258b0e19a23723ae84b0abd2a723bdd3574c3e0c873b4.nmslib_index.bin
# https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/data/linkers/2023-04-23/umls/tfidf_vectorizer.joblib not found in cache, downloading to /tmp/tmp2ziw81mu
# 100%|██████████| 1.32M/1.32M [00:00<00:00, 1.55MiB/s]
# /opt/conda/lib/python3.12/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator TfidfTransformer from version 1.1.2 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /opt/conda/lib/python3.12/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator TfidfVectorizer from version 1.1.2 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Finished download, copying /tmp/tmp2ziw81mu to cache at /home/onyxia/.scispacy/datasets/37bc06bb7ce30de7251db5f5cbac788998e33b3984410caed2d0083187e01d38.f0994c1b61cc70d0eb96dea4947dddcb37460fb5ae60975013711228c8fe3fba.tfidf_vectorizer.joblib
# https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/data/linkers/2023-04-23/umls/concept_aliases.json not found in cache, downloading to /tmp/tmp77894ss_
# 100%|██████████| 264M/264M [00:14<00:00, 18.6MiB/s]
# Finished download, copying /tmp/tmp77894ss_ to cache at /home/onyxia/.scispacy/datasets/6238f505f56aca33290aab44097f67dd1b88880e3be6d6dcce65e56e9255b7d4.d7f77b1629001b40f1b1bc951f3a890ff2d516fb8fbae3111b236b31b33d6dcf.concept_aliases.json
# https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/data/kbs/2023-04-23/umls_2022_ab_cat0129.jsonl not found in cache, downloading to /tmp/tmpj1oxccze
# 100%|██████████| 628M/628M [00:34<00:00, 19.3MiB/s]
# Finished download, copying /tmp/tmpj1oxccze to cache at /home/onyxia/.scispacy/datasets/d5e593bc2d8adeee7754be423cd64f5d331ebf26272074a2575616be55697632.0660f30a60ad00fffd8bbf084a18eb3f462fd192ac5563bf50940fc32a850a3c.umls_2022_ab_cat0129.jsonl
# https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/data/umls_semantic_type_tree.tsv not found in cache, downloading to /tmp/tmpmrsl2thy
# 100%|██████████| 4.26k/4.26k [00:00<00:00, 6.52MiB/s]
# Finished download, copying /tmp/tmpmrsl2thy to cache at /home/onyxia/.scispacy/datasets/21a1012c532c3a431d60895c509f5b4d45b0f8966c4178b892190a302b21836f.330707f4efe774134872b9f77f0e3208c1d30f50800b3b39a6b8ec21d9adf1b7.umls_semantic_type_tree.tsv

# %%
# Échantillon aléatoire de 250 lignes (modifiable)
sample_df = df.sample(n=250, random_state=42)
text = " ".join(sample_df['case_text'].astype(str))

# Applique le modèle NLP sur tout le texte d’un coup (plus rapide et propre)
doc = nlp(text)

# Récupère les entités détectées
medical_terms = [ent.lemma_.lower() for ent in doc.ents]

# Ajoute des mots personnalisés si besoin
additional_terms = ["one", "two", "three", "day", "daily", "month"]
medical_terms.extend(additional_terms)

# %%
from collections import Counter

# Compte les occurrences des termes médicaux
term_counts = Counter(medical_terms)

# Affiche les 20 termes les plus fréquents
most_common_terms = term_counts.most_common(40)

# Affichage propre
print("Top 20 des termes médicaux les plus fréquents :")
for term, count in most_common_terms:
    print(f"{term}: {count}")
# Out:
# Top 20 des termes médicaux les plus fréquents :
# patient: 936
# day: 370
# month: 287
# increase: 200
# treatment: 197
# week: 190
# year: 186
# level: 180
# negative: 179
# diagnosis: 154
# figure: 147
# diagnose: 132
# admission: 125
# lesion: 125
# patient's: 122
# finding: 117
# case: 115
# positive: 114
# hospital: 103
# decrease: 102
# age: 100
# symptom: 99
# woman: 87
# follow-up: 87
# result: 86
# severe: 84
# fever: 82
# mass: 79
# bilateral: 78
# physical examination: 78
# detect: 74
# presence: 71
# tumor: 71
# discharge: 69
# history: 69
# mri: 69
# elevated: 69
# associate with: 69
# treat with: 67
# examination: 67

# %%
# Génère le nuage de mots
medical_bagofwords = " ".join(medical_terms)
print(medical_terms)

wc = WordCloud(background_color="white", repeat=True, mask=mask, stopwords=STOPWORDS)
wc.generate(medical_bagofwords)

plt.axis("off")
plt.imshow(wc, interpolation="bilinear")
plt.show()
# Out:
# ['male', 'admit', 'department of surgery', 'clinical emergency hospital', 'bucharest', 'height', 'meter', 'multiple trauma', 'haemoperitoneum', 'splenic rupture', 'blunt bladder injury', 'microscopic', 'hematuria', 'mild cerebral contusion', 'retrograde', 'amnesia', 'facial abrasion', 'blunt ch trauma', 'blunt right knee injury', 'medical history', 'hepatitis c virus infection', 'admission', 'gcs=15', 'retrograde', 'amnesia', 'bp=122/70 mmhg', 'hr=75/min', 'sinus rhythm', 'rr=14/min', 'abdoman', 'soft', 'no rebound', 'guarding', 'tender', 'left upper quadrant', 'epigastrium', 'abdominal ultrasound', 'perisplenic fluid', 'hypoechoic splenic area', 'contrast ct', 'splenic laceration', 'spleen', 'upper pole', 'capsule disruption', 'splenic pedicle', 'perihepatic', 'perisplenic', 'blood', 'pelvis', 'presence', 'grade iv splenic injury', 'aast-ois', 'moderate', 'haemoperitoneum', 'performance', 'splenic angiography', 'heterogeneous', 'contrast', 'splenic parenchyma', 'contrast extravasation', 'proximal', 'sae', 'fibrin sealant', 'angiographic check', 'contrast extravasation', 'post-procedure progress', 'ct', 'day', 'post-embolization', 'peripheral blood smear', 'post-embolization', 'howell-jolly antibody', 'woman', 'diagnosis', 'mg', 'clinical symptom', 'severe', 'progressive', 'muscle weakness', 'compromise', 'respiratory muscle', 'intubation', 'intensive care unit', 'class v', 'myasthenia gravis foundation of america', 'clinic', 'classification', 'improvement', 'treatment', 'mg', 'corticosteroid', 'azathioprine', 'pyridostigmine', 'thymectomy', 'surgery', 'low', 'dose', 'daily', 'intercalation', 'azathioprine', 'daily dose', 'pyridostigmine', 'never', 'mg', 'symptom', 'dose', 'medication', 'daily', 'intake', 'prednisone', 'pyridostigmine', 'episode', 'disease relapse', 'critical muscle', 'symptom', 'worsen', 'continuous', 'breathlessness', 'refractory clinical status', 'alternative', 'treatment', 'physician', 'high-dose', 'vitamin d', 'treatment', 'potential', 'treatment', 'vitamin d', 'autoimmune disease', 'vitamin d', 'calcium-free diet', 'prevent', 'hypercalcemia', 'medication', 'time', 'massive', 'dose', 'vitamin d', 'treatment', 'experimental', 'improvement', 'fatigue', 'muscle weakness', 'asymptomatic', 'diagnose', 'decrease', 'medication dose', 'neurologist', 'suspend pyridostigmine', 'decrease', 'prednisone', 'mg/5', 'day', 'decrease', 'azathioprine', 'anti-acetylcholine receptor', 'decrease', 'nmol/l', 'figure', 'symptom', 'antibody', 'level', 'linear improvement', 'serum', '25(oh)d', 'involuntary', 'blind', 'vitamin d', 'discontinuation', 'bad-quality compounding', 'vitamin d', 'severe', 'relapse', 'respiratory insufficiency', 'intubation', 'cause', 'relapse', 'blood test', 'sample analysis', 'vitamin d', '25-hydroxy vitamin d', 'improvement', 'relapse', 'refractory', 'increase', 'dose', 'medication', 'vitamin d', 'episode', 'antibody', 'increase', 'nmol/l', 'vitamin d', 'decrease', 'therapy', 'calcium serum level', '24-hour urinary calcium never', 'parathyroid hormone', 'pth', 'decrease', 'noticeable', 'correlation', 'vitamin d', 'mg', 'severity', 'antibody level', 'patient', 'electromyography', 'follow-up', 'result', 'case', 'association', 'myoclonus dystonia syndrome', 'russell-silver syndrome', 'mupd7', 'variant', 'right-handed female', 'mupd7', 'pcr-based', 'analysis', 'absence', 'sgce', 'mutation', 'feature', 'russell-silver syndrome', 'age', 'evaluation', 'abnormal', 'movement', 'symptom', 'generalize body jerk', 'involvement', 'head', 'extremity', 'movement', 'painful', 'non-suppressible', 'rest', 'action', 'generalize dystonia', 'low extremity', 'frequent', 'arching', 'back', 'frequent', 'fall', 'physical exam', 'generalize', 'action-induced myoclonus', 'dystonic posturing', 'affect', 'neck', 'trunk', 'extremitie', 'video', 'multiple', 'medication', 'levetiracetam', 'topiramate', 'gabapentin', 'propranolol', 'clonazepam', 'tetrabenazine', 'symptom', 'functional', 'assistance', 'multiple', 'adl', 'shower', 'up/d ...
