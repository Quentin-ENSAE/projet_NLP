# %%
import os
import s3fs
import pandas as pd

# %% [markdown]
# # 1. Chargement des fichiers

# %% [markdown]
#
# > Chargement à partir du serveur AWS du fichier full_df qui contient l'ensemble des cas cliniques en format texte ainsi qu'un "**case_id**"
# >
# > Chargement à partir du fichier 'df_metadata' qui contient les diagnostique et les keywords lié à chaque cas cliniques ainsi qu'un "**case_id**"

# %%
# Create filesystem object
S3_ENDPOINT_URL = "https://" + os.environ["AWS_S3_ENDPOINT"]
fs = s3fs.S3FileSystem(client_kwargs={'endpoint_url': S3_ENDPOINT_URL})

# %%
print(fs.ls('s3://quentin1999'))
# Out:
# ['quentin1999/Data_Projet_NLP', 'quentin1999/full_df']

# %%
BUCKET = "s3://quentin1999/Data_Projet_NLP"
FILE_KEY_S3 = "full_df"
FILE_PATH_S3 = BUCKET + "/" + FILE_KEY_S3

with fs.open(FILE_PATH_S3, mode="rb") as file_in:
    full_df = pd.read_parquet(file_in)

# %%
full_df.head()
# Out:
#     age        case_id                                          case_text  \
# 0  53.0  PMC3738355_01  A 53-year-old woman presented with a 10-year h...
# 0  69.0  PMC5015624_01  A 69-year-old Caucasian female with coronary a...
# 0  60.0  PMC6381877_01  A 60-year-old male smoker presented with persi...
# 0  41.0  PMC5912312_01  A 41-year-old female with a past medical histo...
# 1  51.0  PMC5912312_02  A 51-year-old male with a history of SCAD pres...
#
#    gender
# 0  Female
# 0  Female
# 0    Male
# 0  Female
# 1    Male

# %%
full_df["pmcid"] = full_df["case_id"].apply(lambda x: x.split("_")[0])
full_df.head(2)
# Out:
#     age        case_id                                          case_text  \
# 0  53.0  PMC3738355_01  A 53-year-old woman presented with a 10-year h...
# 0  69.0  PMC5015624_01  A 69-year-old Caucasian female with coronary a...
#
#    gender       pmcid
# 0  Female  PMC3738355
# 0  Female  PMC5015624

# %%
df_metadata = pd.read_parquet('data/df_metadata')

print('nombre de ligne avec keywords non vide : ' + str(df_metadata.keywords.notna().sum()))
print('nombre de ligne avec major_mesh_terms non vide : ' + str(df_metadata.major_mesh_terms.notna().sum()))
# Out:
# nombre de ligne avec keywords non vide : 59628
# nombre de ligne avec major_mesh_terms non vide : 13211

# %%
df_metadata.head()
# Out:
#                                              authors  case_amount  \
# 0  [Wenhua Liang, Jingjing Lu, Mingwei Qin, Xinti...            1
# 1  [Payal J Shah, Brian Ellis, Lauren R DiGiovine...            1
# 2  [Nobuhiko Seki, Maika Natsume, Ryosuke Ochiai,...            1
# 3  [Ali Raza Ghani, Faisal Inayat, Nouman Safdar ...            9
# 4  [Xiangyi Kong, Dongmei Li, Yanguo Kong, Dingro...            1
#
#                            doi                              journal  \
# 0     10.1258/arsr.2012.120031                Acta Radiol Short Rep
# 1             10.3205/oc000036                 GMS Ophthalmol Cases
# 2            10.1159/000493088                       Case Rep Oncol
# 3     10.1177/2324709618770479  J Investig Med High Impact Case Rep
# 4  10.1097/MD.0000000000005657                 Medicine (Baltimore)
#
#                        journal_detail  \
# 0  2012 Jul 31;1(6):arsr.2012.120031.
# 1                 2015 Dec 2;5:Doc14.
# 2            2019 Jan 21;12(1):91-97.
# 3     2018 Apr 18;6:2324709618770479.
# 4               2017 Jan;96(4):e5657.
#
#                                             keywords   license  \
# 0  [vascular tumor, diagnostic imaging, liver, pa...  CC BY-NC
# 1  [mri, aortic arch, carotid artery stenosis, ca...     CC BY
# 2  [bevacizumab, egfr mutation, erlotinib, lung c...  CC BY-NC
# 3  [acute coronary syndrome, diagnosis, fibromusc...     CC BY
# 4                                               None     CC BY
#
#                                         link  \
# 0  https://pubmed.ncbi.nlm.nih.gov/23986846/
# 1  https://pubmed.ncbi.nlm.nih.gov/27625958/
# 2  https://pubmed.ncbi.nlm.nih.gov/30792648/
# 3  https://pubmed.ncbi.nlm.nih.gov/29707593/
# 4  https://pubmed.ncbi.nlm.nih.gov/28121922/
#
#                                     major_mesh_terms  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4  [Adenoma, Oxyphilic / pathology, Ki-67 Antigen...
#
#                                           mesh_terms       pmcid      pmid  \
# 0                                     [Case Reports]  PMC3738355  23986846
# 1                                     [Case Reports]  PMC5015624  27625958
# 2                                     [Case Reports]  PMC6381877  30792648
# 3                                                 []  PMC5912312  29707593
# 4  [Adenoma, Oxyphilic / pathology, Ki-67 Antigen...  PMC5287946  28121922
#
#                                                title  year
# 0      Littoral cell angioma mimicking hepatic tumor  2012
# 1  Central retinal artery occlusion following las...  2015
# 2  Promising Combination Therapy with Bevacizumab...  2019
# 3  Spontaneous Coronary Artery Dissection: A Case...  2018
# 4  Malignant adenohypophysis spindle cell oncocyt...  2017

# %% [markdown]
# # 2. Analyse MeSH terms

# %% [markdown]
# > Suppression des articles avec plus d'un cas cliniques (case_amount > 1) du df_metadata
# >
# > Suppression des articles avec colonne major_mesh_terms vide

# %%
df_metadata_mesh = df_metadata.copy(deep=True)

df_metadata_mesh.dropna(subset='major_mesh_terms', inplace=True)
df_metadata_mesh.query("case_amount <= 1", inplace=True)

df_metadata_mesh.head(10)
# Out:
#                                               authors  case_amount  \
# 4   [Xiangyi Kong, Dongmei Li, Yanguo Kong, Dingro...            1
# 18  [Stéphane Helleringer, Géraldine Duthé, Almamy...            1
# 19  [Jian-Min Jin, Peng Bai, Wei He, Fei Wu, Xiao-...            1
# 24  [Kamal Khademvatani, Yousef Rezaei, Abdollah K...            1
# 34  [Teppei Tanaka, Motoharu Hayakawa, Akiyo Sadat...            1
# 38                               [A Katz, P Zalewski]            1
# 42  [Hamza Dergamoun, Abdelaziz El Gdaouni, Imad Z...            1
# 46  [Cindy Y G Noben, Frans J N Nijhuis, Angelique...            1
# 49  [Yukiko Mikami, Tomonori Nagai, Yousuke Gomi, ...            1
# 50    [Bartosz Hudzik, Lech Poloński, Mariusz Gąsior]            1
#
#                                 doi                  journal  \
# 4       10.1097/MD.0000000000005657     Medicine (Baltimore)
# 18                10.1111/tmi.12012      Trop Med Int Health
# 19         10.3389/fpubh.2020.00152      Front Public Health
# 24             10.12659/AJCR.890607            Am J Case Rep
# 34         10.2176/nmc.cr.2013-0007  Neurol Med Chir (Tokyo)
# 38           10.1038/sj.bjc.6601478              Br J Cancer
# 42  10.11604/pamj.2022.43.106.36588            Pan Afr Med J
# 46          10.1186/1471-2458-12-43        BMC Public Health
# 49        10.1186/s13256-015-0790-6           J Med Case Rep
# 50        10.1007/s11739-015-1384-4         Intern Emerg Med
#
#                          journal_detail  \
# 4                 2017 Jan;96(4):e5657.
# 18                2013 Jan;18(1):27-34.
# 19                   2020 Apr 29;8:152.
# 24                2014 Jul 13;15:300-3.
# 34                   2014;54(2):155-60.
# 38  2003 Dec;89 Suppl 2(Suppl 2):S15-8.
# 42                  2022 Oct 27;43:106.
# 46                   2012 Jan 18;12:43.
# 49                    2016 Jan 18;10:9.
# 50            2016 Dec;11(8):1139-1140.
#
#                                              keywords            license  \
# 4                                                None              CC BY
# 18                                               None  author_manuscript
# 19  [covid-19, sars, sars-cov-2, female, gender, m...              CC BY
# 24  [echocardiography, leiomyoma, pulmonary emboli...         NO-CC CODE
# 34                                               None        CC BY-NC-ND
# 38                                               None              CC BY
# 42  [renal cell carcinoma, case report, gallbladde...              CC BY
# 46                                               None              CC BY
# 49                                               None              CC BY
# 50                                               None              CC BY
#
#                                          link  \
# 4   https://pubmed.ncbi.nlm.nih.gov/28121922/
# 18  https://pubmed.ncbi.nlm.nih.gov/23130912/
# 19  https://pubmed.ncbi.nlm.nih.gov/32411652/
# 24  https://pubmed.ncbi.nlm.nih.gov/25061497/
# 34  https://pubmed.ncbi.nlm.nih.gov/24418783/
# 38  https://pubmed.ncbi.nlm.nih.gov/14661048/
# 42  https://pubmed.ncbi.nlm.nih.gov/36699978/
# 46  https://pubmed.ncbi.nlm.nih.gov/22257557/
# 49  https://pubmed.ncbi.nlm.nih.gov/26781485/
# 50  https://pubmed.ncbi.nlm.nih.gov/26758273/
#
#                                      major_mesh_terms  \
# 4   [Adenoma, Oxyphilic / pathology, Ki-67 Antigen...
# 18  [Cause of Death, Data Collection / standards, ...
# 19  [COVID-19 / epidemiology, COVID-19 / mortality...
# 24  [Pulmonary Embolism / etiology, Uterine Neopla...
# 34  [Arteriovenous Fistula / therapy, Carotid Arte...
# 38  [Antineoplastic Agents / therapeutic use, Brai...
# 42  [Carcinoma, Renal Cell / diagnosis, Carcinoma,...
# 46  [Disabled Persons, Occupational Health Service...
# 49  [Antibiotics, Antineoplastic / therapeutic use...
# 50  [Electrocardiography / standards, Tricuspid Va...
#
#                                            mesh_terms       pmcid      pmid  \
# 4   [Adenoma, Oxyphilic / pathology, Ki-67 Antigen...  PMC5287946  28121922
# 18  [Cause of Death, Data Collection / standards, ...  PMC3678730  23130912
# 19  [COVID-19 / epidemiology, COVID-19 / mortality...  PMC7201103  32411652
# 24  [Pulmonary Embolism / etiology, Uterine Neopla...  PMC4108191  25061497
# 34  [Arteriovenous Fistula / therapy, Carotid Arte...  PMC4508704  24418783
# 38  [Antineoplastic Agents / therapeutic use, Brai...  PMC2750244  14661048
# 42  [Carcinoma, Renal Cell / diagnosis, Carcinoma,...  PMC9834804  36699978
# 46  [Disabled Persons, Occupational Health Service...  PMC3273437  22257557
# 49  [Antibiotics, Antineoplastic / therapeutic use...  PMC4717627  26781485
# 50  [Electrocardiography / standards, Tricuspid Va...  PMC5114320  26758273
#
#                                                 title  year
# 4   Malignant adenohypophysis spindle cell oncocyt...  2017
# 18  Misclassification of pregnancy-related deaths ...  2013
# 19  Gender Differences in Patients With COVID-19: ...  2020
# 24  Acute pulmonary embolism caused by enlarged ut...  2014
# 34  Transvenous embolization for carotid-cavernous...  2014
# 38  Quality-of-life benefits and evidence of antit...  2003
# 42  Renal cell carcinoma with gallbladder metastas...  2022
# 46  Design of a trial-based economic evaluation on...  2012
# 49  Methotrexate and actinomycin D chemotherapy in...  2016
# 50  Lancisi sign: giant C-V waves of tricuspid reg...  2016

# %%
df_metadata_mesh.shape
# Out:
# (10718, 14)

# %% [markdown]
# # 3. Fusionner les 2 datasets

# %%
df_merged = pd.merge(df_metadata_mesh, full_df, how='left')
df_merged.head(2)
# Out:
#                                              authors  case_amount  \
# 0  [Xiangyi Kong, Dongmei Li, Yanguo Kong, Dingro...            1
# 1  [Stéphane Helleringer, Géraldine Duthé, Almamy...            1
#
#                            doi               journal         journal_detail  \
# 0  10.1097/MD.0000000000005657  Medicine (Baltimore)  2017 Jan;96(4):e5657.
# 1            10.1111/tmi.12012   Trop Med Int Health  2013 Jan;18(1):27-34.
#
#   keywords            license                                       link  \
# 0     None              CC BY  https://pubmed.ncbi.nlm.nih.gov/28121922/
# 1     None  author_manuscript  https://pubmed.ncbi.nlm.nih.gov/23130912/
#
#                                     major_mesh_terms  \
# 0  [Adenoma, Oxyphilic / pathology, Ki-67 Antigen...
# 1  [Cause of Death, Data Collection / standards, ...
#
#                                           mesh_terms       pmcid      pmid  \
# 0  [Adenoma, Oxyphilic / pathology, Ki-67 Antigen...  PMC5287946  28121922
# 1  [Cause of Death, Data Collection / standards, ...  PMC3678730  23130912
#
#                                                title  year   age  \
# 0  Malignant adenohypophysis spindle cell oncocyt...  2017  30.0
# 1  Misclassification of pregnancy-related deaths ...  2013  15.0
#
#          case_id                                          case_text  gender
# 0  PMC5287946_01  A 30-year-old man came to Peking Union Medical...    Male
# 1  PMC3678730_01  For each death, the DSS has systematically rec...  Female

# %%
columns = ['pmcid','title', 'gender', 'case_text', 'keywords', 'major_mesh_terms', 'mesh_terms', 'journal', 'doi']
df = df_merged[columns]
df.head(3)
# Out:
#         pmcid                                              title  gender  \
# 0  PMC5287946  Malignant adenohypophysis spindle cell oncocyt...    Male
# 1  PMC3678730  Misclassification of pregnancy-related deaths ...  Female
# 2  PMC7201103  Gender Differences in Patients With COVID-19: ...  Female
#
#                                            case_text  \
# 0  A 30-year-old man came to Peking Union Medical...
# 1  For each death, the DSS has systematically rec...
# 2  The demographic and clinical characteristics a...
#
#                                             keywords  \
# 0                                               None
# 1                                               None
# 2  [covid-19, sars, sars-cov-2, female, gender, m...
#
#                                     major_mesh_terms  \
# 0  [Adenoma, Oxyphilic / pathology, Ki-67 Antigen...
# 1  [Cause of Death, Data Collection / standards, ...
# 2  [COVID-19 / epidemiology, COVID-19 / mortality...
#
#                                           mesh_terms               journal  \
# 0  [Adenoma, Oxyphilic / pathology, Ki-67 Antigen...  Medicine (Baltimore)
# 1  [Cause of Death, Data Collection / standards, ...   Trop Med Int Health
# 2  [COVID-19 / epidemiology, COVID-19 / mortality...   Front Public Health
#
#                            doi
# 0  10.1097/MD.0000000000005657
# 1            10.1111/tmi.12012
# 2     10.3389/fpubh.2020.00152

# %% [markdown]
# # 4. Sauvegarde dataframe final 'df'

# %%
file = "df_final"
path = f'data/{file}'

if not os.path.exists(path):
    df.to_parquet(path)
else:
    print("Le fichier 'df_metadata' existe déjà. Aucune action effectuée.")
